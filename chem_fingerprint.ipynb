# %%
import numpy as np
import matplotlib

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
	
# Set such that PDF fonts export in a manner that they
# are editable in illustrator/affinity
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# set to define axes linewidths
matplotlib.rcParams['axes.linewidth'] = 0.5

# this defines some prefactors so inline figures look nice
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

matplotlib.rc('font', **font)

from scipy.cluster.hierarchy import dendrogram, linkage, leaves_list,fcluster
import matplotlib.patches as mpatches

from finches import CALVADOS_frontend, Mpipi_frontend
cf = CALVADOS_frontend()
mf = Mpipi_frontend()
from sparrow.data.amino_acids import VALID_AMINO_ACIDS
from tqdm import tqdm
import itertools
import protfasta
from sparrow import Protein
# Out:
# /home/wenyuantong/.local/share/pipx/venvs/jupyterlab/lib/python3.12/site-packages/finches/forcefields/calvados.py:236: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.038286503882254706' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   r.loc['H','q'] = 1. / ( 1 + 10**(self.pH-6) )

# %%
mode = 'calvados'

# note - dipeptides give much cleaner clusters than tripeptides...
all_peptides = []
for idx, aa1 in enumerate(VALID_AMINO_ACIDS):
    
    for aa2 in VALID_AMINO_ACIDS[idx:]:
        all_peptides.append((aa1 + aa2)*10)

# %%
all_eps =[]
for s1 in tqdm(all_peptides):
    tmp = []
    for s2 in all_peptides:
        if mode == 'calvados':
            tmp.append(cf.epsilon(s1,s2))
        elif mode == 'mpipi':
            tmp.append(mf.epsilon(s1,s2))
    all_eps.append(tmp)

all_eps = np.array(all_eps)
# Out:
# 100%|█████████████████████████████████████████| 210/210 [00:09<00:00, 21.93it/s]

# %%
row_linkage = linkage(all_eps, method='ward', optimal_ordering=True)
col_linkage = linkage(all_eps.T, method='ward',optimal_ordering=True)  # Transpose for column clustering
row_order = leaves_list(row_linkage)
col_order = leaves_list(col_linkage)

# %%
reordered_matrix = all_eps[row_order, :][:, col_order]

if mode == 'calvados':
    plt.imshow(reordered_matrix, vmin=-25, vmax=25,cmap='PRGn',interpolation='None', aspect='auto', origin='lower')
elif mode == 'mpipi':
    plt.imshow(reordered_matrix, vmin=-15, vmax=15,cmap='PRGn',interpolation='None', aspect='auto', origin='lower')

# %%
# define the number of clusters (0.5)
nclusters=18

# find nclusters*2 clusters using maxclust
clusters = fcluster(row_linkage, t=nclusters*2, criterion='maxclust')

# now plot everything
fig, ax = plt.subplots(figsize=(16, 16))


cax = ax.matshow(reordered_matrix, aspect='auto', origin='lower', cmap='PRGn', vmin=-25, vmax=25)

# Add a color bar for the heatmap

# cluster membership sidebar - rather than the chaos of a dendrogram we're gonna alternative white/black to deliniate
# cluster identity

current_cluster = clusters[row_order][0]
possible_colors = ['k','w']
color_idx = 0
                   
current_color = 'k'
color_labels = []
color_labels.append(current_color)

for c in clusters[row_order][1:]:
    if c == current_cluster:
         pass
    else:
        current_cluster = c
        
        if color_idx + 1 == len(possible_colors):
            color_idx = 0
            current_color = possible_colors[color_idx]
        else:
            color_idx = color_idx + 1            
            current_color = possible_colors[color_idx]
        
    color_labels.append(current_color)

#cluster_colors = ['k', 'w']*(nclusters)
#color_labels = [cluster_colors[i-1] for i in clusters[row_order]]  # Match cluster ID to color

offset = 20
for ypos, c in enumerate(color_labels):
    ax.add_patch(mpatches.Rectangle((reordered_matrix.shape[0], ypos), offset, 10, color=c, edgecolor=None))

ax.set_xlim(right=reordered_matrix.shape[0]+offset)  


plt.savefig(f'fingerprint_clusters_{mode}.pdf')

# %%
cluster_indices_dict = {}
for index, cluster_id in enumerate(clusters):
    if cluster_id not in cluster_indices_dict:
        cluster_indices_dict[cluster_id] = []
    cluster_indices_dict[cluster_id].append(index)


# define the domains in each cluster (1,2,... from bottom to top)
cluster_domains = {}
for i in range(1, 1+nclusters*2):

    cluster_domains[i] = []
    for idx in cluster_indices_dict[i]:
        cluster_domains[i].append(all_peptides[idx])

# %%
outdict = {}
for k in cluster_domains:
    for idx, s in enumerate(cluster_domains[k]):
        outdict[f"{k}_{idx}"]  = s
protfasta.write_fasta(outdict, f'fingerprint_clusters_{mode}.fasta')

# %%
cluster_domains
# Out:
# {1: ['DDDDDDDDDDDDDDDDDDDD', 'DEDEDEDEDEDEDEDEDEDE', 'EEEEEEEEEEEEEEEEEEEE'],
#  2: ['CDCDCDCDCDCDCDCDCDCD',
#   'CECECECECECECECECECE',
#   'DGDGDGDGDGDGDGDGDGDG',
#   'DHDHDHDHDHDHDHDHDHDH',
#   'EGEGEGEGEGEGEGEGEGEG',
#   'EHEHEHEHEHEHEHEHEHEH'],
#  3: ['DNDNDNDNDNDNDNDNDNDN',
#   'DPDPDPDPDPDPDPDPDPDP',
#   'DQDQDQDQDQDQDQDQDQDQ',
#   'DSDSDSDSDSDSDSDSDSDS',
#   'DTDTDTDTDTDTDTDTDTDT',
#   'ENENENENENENENENENEN',
#   'EPEPEPEPEPEPEPEPEPEP',
#   'EQEQEQEQEQEQEQEQEQEQ',
#   'ESESESESESESESESESES',
#   'ETETETETETETETETETET'],
#  4: ['ADADADADADADADADADAD',
#   'AEAEAEAEAEAEAEAEAEAE',
#   'DVDVDVDVDVDVDVDVDVDV',
#   'EVEVEVEVEVEVEVEVEVEV'],
#  5: ['DFDFDFDFDFDFDFDFDFDF',
#   'DWDWDWDWDWDWDWDWDWDW',
#   'DYDYDYDYDYDYDYDYDYDY',
#   'EFEFEFEFEFEFEFEFEFEF',
#   'EWEWEWEWEWEWEWEWEWEW',
#   'EYEYEYEYEYEYEYEYEYEY'],
#  6: ['DIDIDIDIDIDIDIDIDIDI',
#   'DLDLDLDLDLDLDLDLDLDL',
#   'DMDMDMDMDMDMDMDMDMDM',
#   'EIEIEIEIEIEIEIEIEIEI',
#   'ELELELELELELELELELEL',
#   'EMEMEMEMEMEMEMEMEMEM'],
#  7: ['AAAAAAAAAAAAAAAAAAAA', 'AVAVAVAVAVAVAVAVAVAV', 'VVVVVVVVVVVVVVVVVVVV'],
#  8: ['APAPAPAPAPAPAPAPAPAP',
#   'ATATATATATATATATATAT',
#   'NVNVNVNVNVNVNVNVNVNV',
#   'PVPVPVPVPVPVPVPVPVPV',
#   'QVQVQVQVQVQVQVQVQVQV',
#   'SVSVSVSVSVSVSVSVSVSV',
#   'TVTVTVTVTVTVTVTVTVTV'],
#  9: ['ACACACACACACACACACAC',
#   'AGAGAGAGAGAGAGAGAGAG',
#   'AHAHAHAHAHAHAHAHAHAH',
#   'ANANANANANANANANANAN',
#   'AQAQAQAQAQAQAQAQAQAQ',
#   'ASASASASASASASASASAS',
#   'CVCVCVCVCVCVCVCVCVCV',
#   'GVGVGVGVGVGVGVGVGVGV',
#   'HVHVHVHVHVHVHVHVHVHV'],
#  10: ['CCCCCCCCCCCCCCCCCCCC',
#   'CGCGCGCGCGCGCGCGCGCG',
#   'CHCHCHCHCHCHCHCHCHCH',
#   'GGGGGGGGGGGGGGGGGGGG',
#   'GHGHGHGHGHGHGHGHGHGH',
#   'GNGNGNGNGNGNGNGNGNGN',
#   'GQGQGQGQGQGQGQGQGQGQ',
#   'GSGSGSGSGSGSGSGSGSGS'],
#  11: ['CNCNCNCNCNCNCNCNCNCN',
#   'CPCPCPCPCPCPCPCPCPCP',
#   'CQCQCQCQCQCQCQCQCQCQ',
#   'CSCSCSCSCSCSCSCSCSCS',
#   'CTCTCTCTCTCTCTCTCTCT',
#   'GPGPGPGPGPGPGPGPGPGP',
#   'GTGTGTGTGTGTGTGTGTGT',
#   'HHHHHHHHHHHHHHHHHHHH',
#   'HNHNHNHNHNHNHNHNHNHN',
#   'HQHQHQHQHQHQHQHQHQHQ',
#   'HSHSHSHSHSHSHSHSHSHS'],
#  12: ['HPHPHPHPHPHPHPHPHPHP',
#   'HTHTHTHTHTHTHTHTHTHT',
#   'NNNNNNNNNNNNNNNNNNNN',
#   'NPNPNPNPNPNPNPNPNPNP',
#   'NQNQNQNQNQNQNQNQNQNQ',
#   'NSNSNSNSNSNSNSNSNSNS',
#   'NTNTNTNTNTNTNTNTNTNT',
#   'PPPPPPPPPPPPPPPPPPPP',
#   'PQPQPQPQPQPQPQPQPQPQ',
#   'PSPSPSPSPSPSPSPSPSPS',
#   'PTPTPTPTPTPTPTPTPTPT',
#   'QQQQQQQQQQQQQQQQQQQQ',
#   'QSQSQSQSQSQSQSQSQSQS',
#   'QTQTQTQTQTQTQTQTQTQT',
#   'SSSSSSSSSSSSSSSSSSSS',
#   'STSTSTSTSTSTSTSTSTST',
#   'TTTTTTTTTTTTTTTTTTTT'],
#  13: ['DRDRDRDRDRDRDRDRDRDR', 'ERERERERERERERERERER'],
#  14: ['DKDKDKDKDKDKDKDKDKDK', 'EKEKEKEKEKEKEKEKEKEK'],
#  15: ['ILILILILILILILILILIL', 'LLLLLLLLLLLLLLLLLLLL', 'LMLMLMLMLMLMLMLMLMLM'],
#  16: ['IIIIIIIIIIIIIIIIIIII', 'IMIMIMIMIMIMIMIMIMIM', 'MMMMMMMMMMMMMMMMMMMM'],
#  17: ['LWLWLWLWLWLWLWLWLWLW', 'LYLYLYLYLYLYLYLYLYLY'],
#  18: ['FIFIFIFIFIFIFIFIFIFI',
#   'FLFLFLFLFLFLFLFLFLFL',
#   'FMFMFMFMFMFMFMFMFMFM',
#   'IWIWIWIWIWIWIWIWIWIW',
#   'IYIYIYIYIYIYIYIYIYIY',
#   'MWMWMWMWMWMWMWMWMWMW',
#   'MYMYMYMYMYMYMYMYMYMY'],
#  19: ['AFAFAFAFAFAFAFAFAFAF',
#   'AWAWAWAWAWAWAWAWAWAW',
#   'AYAYAYAYAYAYAYAYAYAY',
#   'FVFVFVFVFVFVFVFVFVFV',
#   'VWVWVWVWVWVWVWVWVWVW',
#   'VYVYVYVYVYVYVYVYVYVY'],
#  20: ['ININININININININININ',
#   'IPIPIPIPIPIPIPIPIPIP',
#   'IQIQIQIQIQIQIQIQIQIQ',
#   'ISISISISISISISISISIS',
#   'ITITITITITITITITITIT',
#   'MNMNMNMNMNMNMNMNMNMN',
#   'MPMPMPMPMPMPMPMPMPMP',
#   'MQMQMQMQMQMQMQMQMQMQ',
#   'MSMSMSMSMSMSMSMSMSMS',
#   'MTMTMTMTMTMTMTMTMTMT'],
#  21: ['CICICICICICICICICICI',
#   'CLCLCLCLCLCLCLCLCLCL',
#   'CMCMCMCMCMCMCMCMCMCM',
#   'GIGIGIGIGIGIGIGIGIGI',
#   'GLGLGLGLGLGLGLGLGLGL',
#   'GMGMGMGMGMGMGMGMGMGM',
#   'HIHIHIHIHIHIHIHIHIHI',
#   'HLHLHLHLHLHLHLHLHLHL',
#   'HMHMHMHMHMHMHMHMHMHM',
#   'LNLNLNLNLNLNLNLNLNLN',
#   'LPLPLPLPLPLPLPLPLPLP',
#   'LQLQLQLQLQLQLQLQLQLQ',
#   'LSLSLSLSLSLSLSLSLSLS',
#   'LTLTLTLTLTLTLTLTLTLT'],
#  22: ['AIAIAIAIAIAIAIAIAIAI',
#   'ALALALALALALALALALAL',
#   'AMAMAMAMAMAMAMAMAMAM',
#   'IVIVIVIVIVIVIVIVIVIV',
#   'LVLVLVLVLVLVLVLVLVLV',
#   'MVMVMVMVMVMVMVMVMVMV'],
#  23: ['FNFNFNFNFNFNFNFNFNFN',
#   'FPFPFPFPFPFPFPFPFPFP',
#   'FQFQFQFQFQFQFQFQFQFQ',
#   'FSFSFSFSFSFSFSFSFSFS',
#   'FTFTFTFTFTFTFTFTFTFT'],
#  24: ['CFCFCFCFCFCFCFCFCFCF',
#   'FGFGFGFGFGFGFGFGFGFG',
#   'FHFHFHFHFHFHFHFHFHFH',
#   'HWHWHWHWHWHWHWHWHWHW',
#   'HYHYHYHYHYHYHYHYHYHY',
#   'NWNWNWNWNWNWNWNWNWNW',
#   'NYNYNYNYNYNYNYNYNYNY',
#   'PWPWPWPWPWPWPWPWPWPW',
#   'PYPYPYPYPYPYPYPYPYPY',
#   'QWQWQWQWQWQWQWQWQWQW',
#   'QYQYQYQYQYQYQYQYQYQY',
#   'SWSWSWSWSWSWSWSWSWSW',
#   'SYSYSYSYSYSYSYSYSYSY',
#   'TWTWTWTWTWTWTWTWTWTW',
#   'TYTYTYTYTYTYTYTYTYTY'],
#  25: ['CWCWCWCWCWCWCWCWCWCW',
#   'CYCYCYCYCYCYCYCYCYCY',
#   'GWGWGWGWGWGWGWGWGWGW',
#   'GYGYGYGYGYGYGYGYGYGY'],
#  26: ['FFFFFFFFFFFFFFFFFFFF',
#   'FWFWFWFWFWFWFWFWFWFW',
#   'FYFYFYFYFYFYFYFYFYFY',
#   'WWWWWWWWWWWWWWWWWWWW',
#   'WYWYWYWYWYWYWYWYWYWY',
#   'YYYYYYYYYYYYYYYYYYYY'],
#  27: ['IRIRIRIRIRIRIRIRIRIR', 'LRLRLRLRLRLRLRLRLRLR', 'MRMRMRMRMRMRMRMRMRMR'],
#  28: ['FRFRFRFRFRFRFRFRFRFR', 'RWRWRWRWRWRWRWRWRWRW', 'RYRYRYRYRYRYRYRYRYRY'],
#  29: ['CRCRCRCRCRCRCRCRCRCR',
#   'FKFKFKFKFKFKFKFKFKFK',
#   'GRGRGRGRGRGRGRGRGRGR',
#   'HRHRHRHRHRHRHRHRHRHR',
#   'KWKWKWKWKWKWKWKWKWKW',
#   'KYKYKYKYKYKYKYKYKYKY',
#   'NRNRNRNRNRNRNRNRNRNR',
#   'PRPRPRPRPRPRPRPRPRPR',
#   'QRQRQRQRQRQRQRQRQRQR',
#   'RSRSRSRSRSRSRSRSRSRS',
#   'RTRTRTRTRTRTRTRTRTRT'],
#  30: ['ARARARARARARARARARAR', 'RVRVRVRVRVRVRVRVRVRV'],
#  31: ['IKIKIKIKIKIKIKIKIKIK', 'KLKLKLKLKLKLKLKLKLKL', 'KMKMKMKMKMKMKMKMKMKM'],
#  32: ['AKAKAKAKAKAKAKAKAKAK', 'KVKVKVKVKVKVKVKVKVKV'],
#  33: ['CKCKCKCKCKCKCKCKCKCK',
#   'GKGKGKGKGKGKGKGKGKGK',
#   'HKHKHKHKHKHKHKHKHKHK',
#   'KNKNKNKNKNKNKNKNKNKN',
#   'KPKPKPKPKPKPKPKPKPKP',
#   'KQKQKQKQKQKQKQKQKQKQ',
#   'KSKSKSKSKSKSKSKSKSKS',
#   'KTKTKTKTKTKTKTKTKTKT'],
#  34: ['KKKKKKKKKKKKKKKKKKKK'],
#  35: ['KRKRKRKRKRKRKRKRKRKR'],
#  36: ['RRRRRRRRRRRRRRRRRRRR']}

# %%
#manually_curated = protfasta.read_fasta(f'fingerprint_clusters_{mode}.fasta')
manually_curated = protfasta.read_fasta('/home/wenyuantong/Downloads/fingerprint_mpipi_renamed.fasta')

# %%
manually_curated = protfasta.read_fasta('/home/wenyuantong/Downloads/fingerprint_calvados_renamed.fasta')

# %%
for idx, k in enumerate(manually_curated):
    print(f'Cluster {idx+1}')
    Protein(manually_curated[k]).show_sequence(blocksize=30)
# Out:
# Cluster 1
# <p style="font-family:Courier;font-size: 14px"><span style="color:#ff0d0d">D</span><span style="color:#ff0d0d">E</span><span style="color:#ff0d0d">D</span><span style="color:#ff0d0d">E</span><span style="color:#ff0d0d">D</span><span style="color:#ff0d0d">E</span><span style="color:#ff0d0d">D</span><span style="color:#ff0d0d">E</span><span style="color:#ff0d0d">D</span><span style="color:#ff0d0d">E</span><span style="color:#ff0d0d">D</span><span style="color:#ff0d0d">E</span><span style="color:#ff0d0d">D</span><span style="color:#ff0d0d">E</span><span style="color:#ff0d0d">D</span><span style="color:#ff0d0d">E</span><span style="color:#ff0d0d">D</span><span style="color:#ff0d0d">E</span><span style="color:#ff0d0d">D</span><span style="color:#ff0d0d">E</span></p>
# Cluster 2
# <p style="font-family:Courier;font-size: 14px"><span style="color:#ff0d0d">E</span><span style="color:#04700d">G</span><span style="color:#ff0d0d">E</span><span style="color:#04700d">G</span><span style="color:#ff0d0d">E</span><span style="color:#04700d">G</span><span style="color:#ff0d0d">E</span><span style="color:#04700d">G</span><span style="color:#ff0d0d">E</span><span style="color:#04700d">G</span><span style="color:#ff0d0d">E</span><span style="color:#04700d">G</span><span style="color:#ff0d0d">E</span><span style="color:#04700d">G</span><span style="color:#ff0d0d">E</span><span style="color:#04700d">G</span><span style="color:#ff0d0d">E</span><span style="color:#04700d">G</span><span style="color:#ff0d0d">E</span><span style="color:#04700d">G</span></p>
# Cluster 3
# <p style="font-family:Courier;font-size: 14px"><span style="color:#ff0d0d">D</span><span style="color:#04700d">S</span><span style="color:#ff0d0d">D</span><span style="color:#04700d">S</span><span style="color:#ff0d0d">D</span><span style="color:#04700d">S</span><span style="color:#ff0d0d">D</span><span style="color:#04700d">S</span><span style="color:#ff0d0d">D</span><span style="color:#04700d">S</span><span style="color:#ff0d0d">D</span><span style="color:#04700d">S</span><span style="color:#ff0d0d">D</span><span style="color:#04700d">S</span><span style="color:#ff0d0d">D</span><span style="color:#04700d">S</span><span style="color:#ff0d0d">D</span><span style="color:#04700d">S</span><span style="color:#ff0d0d">D</span><span style="color:#04700d">S</span></p>
# Cluster 4
# <p style="font-family:Courier;font-size: 14px"><span style="color:#ff0d0d">E</span><span style="color:#171616">V</span><span style="color:#ff0d0d">E</span><span style="color:#171616">V</span><span style="color:#ff0d0d">E</span><span style="color:#171616">V</span><span style="color:#ff0d0d">E</span><span style="color:#171616">V</span><span style="color:#ff0d0d">E</span><span style="color:#171616">V</span><span style="color:#ff0d0d">E</span><span style="color:#171616">V</span><span style="color:#ff0d0d">E</span><span style="color:#171616">V</span><span style="color:#ff0d0d">E</span><span style="color:#171616">V</span><span style="color:#ff0d0d">E</span><span style="color:#171616">V</span><span style="color:#ff0d0d">E</span><span style="color:#171616">V</span></p>
# Cluster 5
# <p style="font-family:Courier;font-size: 14px"><span style="color:#ff0d0d">D</span><span style="color:#171616">M</span><span style="color:#ff0d0d">D</span><span style="color:#171616">M</span><span style="color:#ff0d0d">D</span><span style="color:#171616">M</span><span style="color:#ff0d0d">D</span><span style="color:#171616">M</span><span style="color:#ff0d0d">D</span><span style="color:#171616">M</span><span style="color:#ff0d0d">D</span><span style="color:#171616">M</span><span style="color:#ff0d0d">D</span><span style="color:#171616">M</span><span style="color:#ff0d0d">D</span><span style="color:#171616">M</span><span style="color:#ff0d0d">D</span><span style="color:#171616">M</span><span style="color:#ff0d0d">D</span><span style="color:#171616">M</span></p>
# Cluster 6
# <p style="font-family:Courier;font-size: 14px"><span style="color:#ff0d0d">E</span><span style="color:#ff9d00">W</span><span style="color:#ff0d0d">E</span><span style="color:#ff9d00">W</span><span style="color:#ff0d0d">E</span><span style="color:#ff9d00">W</span><span style="color:#ff0d0d">E</span><span style="color:#ff9d00">W</span><span style="color:#ff0d0d">E</span><span style="color:#ff9d00">W</span><span style="color:#ff0d0d">E</span><span style="color:#ff9d00">W</span><span style="color:#ff0d0d">E</span><span style="color:#ff9d00">W</span><span style="color:#ff0d0d">E</span><span style="color:#ff9d00">W</span><span style="color:#ff0d0d">E</span><span style="color:#ff9d00">W</span><span style="color:#ff0d0d">E</span><span style="color:#ff9d00">W</span></p>
# Cluster 7
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">A</span><span style="color:#171616">V</span><span style="color:#171616">A</span><span style="color:#171616">V</span><span style="color:#171616">A</span><span style="color:#171616">V</span><span style="color:#171616">A</span><span style="color:#171616">V</span><span style="color:#171616">A</span><span style="color:#171616">V</span><span style="color:#171616">A</span><span style="color:#171616">V</span><span style="color:#171616">A</span><span style="color:#171616">V</span><span style="color:#171616">A</span><span style="color:#171616">V</span><span style="color:#171616">A</span><span style="color:#171616">V</span><span style="color:#171616">A</span><span style="color:#171616">V</span></p>
# Cluster 8
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">A</span><span style="color:#cf30b7">P</span><span style="color:#171616">A</span><span style="color:#cf30b7">P</span><span style="color:#171616">A</span><span style="color:#cf30b7">P</span><span style="color:#171616">A</span><span style="color:#cf30b7">P</span><span style="color:#171616">A</span><span style="color:#cf30b7">P</span><span style="color:#171616">A</span><span style="color:#cf30b7">P</span><span style="color:#171616">A</span><span style="color:#cf30b7">P</span><span style="color:#171616">A</span><span style="color:#cf30b7">P</span><span style="color:#171616">A</span><span style="color:#cf30b7">P</span><span style="color:#171616">A</span><span style="color:#cf30b7">P</span></p>
# Cluster 9
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">A</span><span style="color:#04700d">Q</span><span style="color:#171616">A</span><span style="color:#04700d">Q</span><span style="color:#171616">A</span><span style="color:#04700d">Q</span><span style="color:#171616">A</span><span style="color:#04700d">Q</span><span style="color:#171616">A</span><span style="color:#04700d">Q</span><span style="color:#171616">A</span><span style="color:#04700d">Q</span><span style="color:#171616">A</span><span style="color:#04700d">Q</span><span style="color:#171616">A</span><span style="color:#04700d">Q</span><span style="color:#171616">A</span><span style="color:#04700d">Q</span><span style="color:#171616">A</span><span style="color:#04700d">Q</span></p>
# Cluster 10
# <p style="font-family:Courier;font-size: 14px"><span style="color:#04700d">G</span><span style="color:#04700d">Q</span><span style="color:#04700d">G</span><span style="color:#04700d">Q</span><span style="color:#04700d">G</span><span style="color:#04700d">Q</span><span style="color:#04700d">G</span><span style="color:#04700d">Q</span><span style="color:#04700d">G</span><span style="color:#04700d">Q</span><span style="color:#04700d">G</span><span style="color:#04700d">Q</span><span style="color:#04700d">G</span><span style="color:#04700d">Q</span><span style="color:#04700d">G</span><span style="color:#04700d">Q</span><span style="color:#04700d">G</span><span style="color:#04700d">Q</span><span style="color:#04700d">G</span><span style="color:#04700d">Q</span></p>
# Cluster 11
# <p style="font-family:Courier;font-size: 14px"><span style="color:#04700d">H</span><span style="color:#04700d">Q</span><span style="color:#04700d">H</span><span style="color:#04700d">Q</span><span style="color:#04700d">H</span><span style="color:#04700d">Q</span><span style="color:#04700d">H</span><span style="color:#04700d">Q</span><span style="color:#04700d">H</span><span style="color:#04700d">Q</span><span style="color:#04700d">H</span><span style="color:#04700d">Q</span><span style="color:#04700d">H</span><span style="color:#04700d">Q</span><span style="color:#04700d">H</span><span style="color:#04700d">Q</span><span style="color:#04700d">H</span><span style="color:#04700d">Q</span><span style="color:#04700d">H</span><span style="color:#04700d">Q</span></p>
# Cluster 12
# <p style="font-family:Courier;font-size: 14px"><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span></p>
# Cluster 13
# <p style="font-family:Courier;font-size: 14px"><span style="color:#ff0d0d">D</span><span style="color:#2900f5">R</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">R</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">R</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">R</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">R</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">R</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">R</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">R</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">R</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">R</span></p>
# Cluster 14
# <p style="font-family:Courier;font-size: 14px"><span style="color:#ff0d0d">D</span><span style="color:#2900f5">K</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">K</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">K</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">K</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">K</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">K</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">K</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">K</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">K</span><span style="color:#ff0d0d">D</span><span style="color:#2900f5">K</span></p>
# Cluster 15
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">L</span><span style="color:#171616">M</span><span style="color:#171616">L</span><span style="color:#171616">M</span><span style="color:#171616">L</span><span style="color:#171616">M</span><span style="color:#171616">L</span><span style="color:#171616">M</span><span style="color:#171616">L</span><span style="color:#171616">M</span><span style="color:#171616">L</span><span style="color:#171616">M</span><span style="color:#171616">L</span><span style="color:#171616">M</span><span style="color:#171616">L</span><span style="color:#171616">M</span><span style="color:#171616">L</span><span style="color:#171616">M</span><span style="color:#171616">L</span><span style="color:#171616">M</span></p>
# Cluster 16
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">I</span><span style="color:#171616">M</span><span style="color:#171616">I</span><span style="color:#171616">M</span><span style="color:#171616">I</span><span style="color:#171616">M</span><span style="color:#171616">I</span><span style="color:#171616">M</span><span style="color:#171616">I</span><span style="color:#171616">M</span><span style="color:#171616">I</span><span style="color:#171616">M</span><span style="color:#171616">I</span><span style="color:#171616">M</span><span style="color:#171616">I</span><span style="color:#171616">M</span><span style="color:#171616">I</span><span style="color:#171616">M</span><span style="color:#171616">I</span><span style="color:#171616">M</span></p>
# Cluster 17
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">L</span><span style="color:#ff9d00">W</span><span style="color:#171616">L</span><span style="color:#ff9d00">W</span><span style="color:#171616">L</span><span style="color:#ff9d00">W</span><span style="color:#171616">L</span><span style="color:#ff9d00">W</span><span style="color:#171616">L</span><span style="color:#ff9d00">W</span><span style="color:#171616">L</span><span style="color:#ff9d00">W</span><span style="color:#171616">L</span><span style="color:#ff9d00">W</span><span style="color:#171616">L</span><span style="color:#ff9d00">W</span><span style="color:#171616">L</span><span style="color:#ff9d00">W</span><span style="color:#171616">L</span><span style="color:#ff9d00">W</span></p>
# Cluster 18
# <p style="font-family:Courier;font-size: 14px"><span style="color:#ff9d00">F</span><span style="color:#171616">M</span><span style="color:#ff9d00">F</span><span style="color:#171616">M</span><span style="color:#ff9d00">F</span><span style="color:#171616">M</span><span style="color:#ff9d00">F</span><span style="color:#171616">M</span><span style="color:#ff9d00">F</span><span style="color:#171616">M</span><span style="color:#ff9d00">F</span><span style="color:#171616">M</span><span style="color:#ff9d00">F</span><span style="color:#171616">M</span><span style="color:#ff9d00">F</span><span style="color:#171616">M</span><span style="color:#ff9d00">F</span><span style="color:#171616">M</span><span style="color:#ff9d00">F</span><span style="color:#171616">M</span></p>
# Cluster 19
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">A</span><span style="color:#ff9d00">W</span><span style="color:#171616">A</span><span style="color:#ff9d00">W</span><span style="color:#171616">A</span><span style="color:#ff9d00">W</span><span style="color:#171616">A</span><span style="color:#ff9d00">W</span><span style="color:#171616">A</span><span style="color:#ff9d00">W</span><span style="color:#171616">A</span><span style="color:#ff9d00">W</span><span style="color:#171616">A</span><span style="color:#ff9d00">W</span><span style="color:#171616">A</span><span style="color:#ff9d00">W</span><span style="color:#171616">A</span><span style="color:#ff9d00">W</span><span style="color:#171616">A</span><span style="color:#ff9d00">W</span></p>
# Cluster 20
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">I</span><span style="color:#04700d">Q</span><span style="color:#171616">I</span><span style="color:#04700d">Q</span><span style="color:#171616">I</span><span style="color:#04700d">Q</span><span style="color:#171616">I</span><span style="color:#04700d">Q</span><span style="color:#171616">I</span><span style="color:#04700d">Q</span><span style="color:#171616">I</span><span style="color:#04700d">Q</span><span style="color:#171616">I</span><span style="color:#04700d">Q</span><span style="color:#171616">I</span><span style="color:#04700d">Q</span><span style="color:#171616">I</span><span style="color:#04700d">Q</span><span style="color:#171616">I</span><span style="color:#04700d">Q</span></p>
# Cluster 21
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">L</span><span style="color:#04700d">Q</span><span style="color:#171616">L</span><span style="color:#04700d">Q</span><span style="color:#171616">L</span><span style="color:#04700d">Q</span><span style="color:#171616">L</span><span style="color:#04700d">Q</span><span style="color:#171616">L</span><span style="color:#04700d">Q</span><span style="color:#171616">L</span><span style="color:#04700d">Q</span><span style="color:#171616">L</span><span style="color:#04700d">Q</span><span style="color:#171616">L</span><span style="color:#04700d">Q</span><span style="color:#171616">L</span><span style="color:#04700d">Q</span><span style="color:#171616">L</span><span style="color:#04700d">Q</span></p>
# Cluster 22
# <p style="font-family:Courier;font-size: 14px"><span style="color:#04700d">H</span><span style="color:#171616">L</span><span style="color:#04700d">H</span><span style="color:#171616">L</span><span style="color:#04700d">H</span><span style="color:#171616">L</span><span style="color:#04700d">H</span><span style="color:#171616">L</span><span style="color:#04700d">H</span><span style="color:#171616">L</span><span style="color:#04700d">H</span><span style="color:#171616">L</span><span style="color:#04700d">H</span><span style="color:#171616">L</span><span style="color:#04700d">H</span><span style="color:#171616">L</span><span style="color:#04700d">H</span><span style="color:#171616">L</span><span style="color:#04700d">H</span><span style="color:#171616">L</span></p>
# Cluster 23
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">A</span><span style="color:#171616">M</span><span style="color:#171616">A</span><span style="color:#171616">M</span><span style="color:#171616">A</span><span style="color:#171616">M</span><span style="color:#171616">A</span><span style="color:#171616">M</span><span style="color:#171616">A</span><span style="color:#171616">M</span><span style="color:#171616">A</span><span style="color:#171616">M</span><span style="color:#171616">A</span><span style="color:#171616">M</span><span style="color:#171616">A</span><span style="color:#171616">M</span><span style="color:#171616">A</span><span style="color:#171616">M</span><span style="color:#171616">A</span><span style="color:#171616">M</span></p>
# Cluster 24
# <p style="font-family:Courier;font-size: 14px"><span style="color:#ff9d00">F</span><span style="color:#04700d">Q</span><span style="color:#ff9d00">F</span><span style="color:#04700d">Q</span><span style="color:#ff9d00">F</span><span style="color:#04700d">Q</span><span style="color:#ff9d00">F</span><span style="color:#04700d">Q</span><span style="color:#ff9d00">F</span><span style="color:#04700d">Q</span><span style="color:#ff9d00">F</span><span style="color:#04700d">Q</span><span style="color:#ff9d00">F</span><span style="color:#04700d">Q</span><span style="color:#ff9d00">F</span><span style="color:#04700d">Q</span><span style="color:#ff9d00">F</span><span style="color:#04700d">Q</span><span style="color:#ff9d00">F</span><span style="color:#04700d">Q</span></p>
# Cluster 25
# <p style="font-family:Courier;font-size: 14px"><span style="color:#04700d">H</span><span style="color:#ff9d00">W</span><span style="color:#04700d">H</span><span style="color:#ff9d00">W</span><span style="color:#04700d">H</span><span style="color:#ff9d00">W</span><span style="color:#04700d">H</span><span style="color:#ff9d00">W</span><span style="color:#04700d">H</span><span style="color:#ff9d00">W</span><span style="color:#04700d">H</span><span style="color:#ff9d00">W</span><span style="color:#04700d">H</span><span style="color:#ff9d00">W</span><span style="color:#04700d">H</span><span style="color:#ff9d00">W</span><span style="color:#04700d">H</span><span style="color:#ff9d00">W</span><span style="color:#04700d">H</span><span style="color:#ff9d00">W</span></p>
# Cluster 26
# <p style="font-family:Courier;font-size: 14px"><span style="color:#ff9d00">F</span><span style="color:#ff9d00">W</span><span style="color:#ff9d00">F</span><span style="color:#ff9d00">W</span><span style="color:#ff9d00">F</span><span style="color:#ff9d00">W</span><span style="color:#ff9d00">F</span><span style="color:#ff9d00">W</span><span style="color:#ff9d00">F</span><span style="color:#ff9d00">W</span><span style="color:#ff9d00">F</span><span style="color:#ff9d00">W</span><span style="color:#ff9d00">F</span><span style="color:#ff9d00">W</span><span style="color:#ff9d00">F</span><span style="color:#ff9d00">W</span><span style="color:#ff9d00">F</span><span style="color:#ff9d00">W</span><span style="color:#ff9d00">F</span><span style="color:#ff9d00">W</span></p>
# Cluster 27
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">M</span><span style="color:#2900f5">R</span><span style="color:#171616">M</span><span style="color:#2900f5">R</span><span style="color:#171616">M</span><span style="color:#2900f5">R</span><span style="color:#171616">M</span><span style="color:#2900f5">R</span><span style="color:#171616">M</span><span style="color:#2900f5">R</span><span style="color:#171616">M</span><span style="color:#2900f5">R</span><span style="color:#171616">M</span><span style="color:#2900f5">R</span><span style="color:#171616">M</span><span style="color:#2900f5">R</span><span style="color:#171616">M</span><span style="color:#2900f5">R</span><span style="color:#171616">M</span><span style="color:#2900f5">R</span></p>
# Cluster 28
# <p style="font-family:Courier;font-size: 14px"><span style="color:#2900f5">R</span><span style="color:#ff9d00">W</span><span style="color:#2900f5">R</span><span style="color:#ff9d00">W</span><span style="color:#2900f5">R</span><span style="color:#ff9d00">W</span><span style="color:#2900f5">R</span><span style="color:#ff9d00">W</span><span style="color:#2900f5">R</span><span style="color:#ff9d00">W</span><span style="color:#2900f5">R</span><span style="color:#ff9d00">W</span><span style="color:#2900f5">R</span><span style="color:#ff9d00">W</span><span style="color:#2900f5">R</span><span style="color:#ff9d00">W</span><span style="color:#2900f5">R</span><span style="color:#ff9d00">W</span><span style="color:#2900f5">R</span><span style="color:#ff9d00">W</span></p>
# Cluster 29
# <p style="font-family:Courier;font-size: 14px"><span style="color:#2900f5">K</span><span style="color:#ff9d00">Y</span><span style="color:#2900f5">K</span><span style="color:#ff9d00">Y</span><span style="color:#2900f5">K</span><span style="color:#ff9d00">Y</span><span style="color:#2900f5">K</span><span style="color:#ff9d00">Y</span><span style="color:#2900f5">K</span><span style="color:#ff9d00">Y</span><span style="color:#2900f5">K</span><span style="color:#ff9d00">Y</span><span style="color:#2900f5">K</span><span style="color:#ff9d00">Y</span><span style="color:#2900f5">K</span><span style="color:#ff9d00">Y</span><span style="color:#2900f5">K</span><span style="color:#ff9d00">Y</span><span style="color:#2900f5">K</span><span style="color:#ff9d00">Y</span></p>
# Cluster 30
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">A</span><span style="color:#2900f5">R</span><span style="color:#171616">A</span><span style="color:#2900f5">R</span><span style="color:#171616">A</span><span style="color:#2900f5">R</span><span style="color:#171616">A</span><span style="color:#2900f5">R</span><span style="color:#171616">A</span><span style="color:#2900f5">R</span><span style="color:#171616">A</span><span style="color:#2900f5">R</span><span style="color:#171616">A</span><span style="color:#2900f5">R</span><span style="color:#171616">A</span><span style="color:#2900f5">R</span><span style="color:#171616">A</span><span style="color:#2900f5">R</span><span style="color:#171616">A</span><span style="color:#2900f5">R</span></p>
# Cluster 31
# <p style="font-family:Courier;font-size: 14px"><span style="color:#2900f5">K</span><span style="color:#171616">L</span><span style="color:#2900f5">K</span><span style="color:#171616">L</span><span style="color:#2900f5">K</span><span style="color:#171616">L</span><span style="color:#2900f5">K</span><span style="color:#171616">L</span><span style="color:#2900f5">K</span><span style="color:#171616">L</span><span style="color:#2900f5">K</span><span style="color:#171616">L</span><span style="color:#2900f5">K</span><span style="color:#171616">L</span><span style="color:#2900f5">K</span><span style="color:#171616">L</span><span style="color:#2900f5">K</span><span style="color:#171616">L</span><span style="color:#2900f5">K</span><span style="color:#171616">L</span></p>
# Cluster 32
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">A</span><span style="color:#2900f5">K</span><span style="color:#171616">A</span><span style="color:#2900f5">K</span><span style="color:#171616">A</span><span style="color:#2900f5">K</span><span style="color:#171616">A</span><span style="color:#2900f5">K</span><span style="color:#171616">A</span><span style="color:#2900f5">K</span><span style="color:#171616">A</span><span style="color:#2900f5">K</span><span style="color:#171616">A</span><span style="color:#2900f5">K</span><span style="color:#171616">A</span><span style="color:#2900f5">K</span><span style="color:#171616">A</span><span style="color:#2900f5">K</span><span style="color:#171616">A</span><span style="color:#2900f5">K</span></p>
# Cluster 33
# <p style="font-family:Courier;font-size: 14px"><span style="color:#2900f5">K</span><span style="color:#04700d">S</span><span style="color:#2900f5">K</span><span style="color:#04700d">S</span><span style="color:#2900f5">K</span><span style="color:#04700d">S</span><span style="color:#2900f5">K</span><span style="color:#04700d">S</span><span style="color:#2900f5">K</span><span style="color:#04700d">S</span><span style="color:#2900f5">K</span><span style="color:#04700d">S</span><span style="color:#2900f5">K</span><span style="color:#04700d">S</span><span style="color:#2900f5">K</span><span style="color:#04700d">S</span><span style="color:#2900f5">K</span><span style="color:#04700d">S</span><span style="color:#2900f5">K</span><span style="color:#04700d">S</span></p>
# Cluster 34
# <p style="font-family:Courier;font-size: 14px"><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span><span style="color:#2900f5">K</span></p>
# Cluster 35
# <p style="font-family:Courier;font-size: 14px"><span style="color:#2900f5">K</span><span style="color:#2900f5">R</span><span style="color:#2900f5">K</span><span style="color:#2900f5">R</span><span style="color:#2900f5">K</span><span style="color:#2900f5">R</span><span style="color:#2900f5">K</span><span style="color:#2900f5">R</span><span style="color:#2900f5">K</span><span style="color:#2900f5">R</span><span style="color:#2900f5">K</span><span style="color:#2900f5">R</span><span style="color:#2900f5">K</span><span style="color:#2900f5">R</span><span style="color:#2900f5">K</span><span style="color:#2900f5">R</span><span style="color:#2900f5">K</span><span style="color:#2900f5">R</span><span style="color:#2900f5">K</span><span style="color:#2900f5">R</span></p>
# Cluster 36
# <p style="font-family:Courier;font-size: 14px"><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span><span style="color:#2900f5">R</span></p>
